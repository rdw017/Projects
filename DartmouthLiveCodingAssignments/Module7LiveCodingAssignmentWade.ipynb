# %% [markdown]
# # Module 7 Live Coding Assignment:
# ## LData Visualization Strategies

# %% [markdown]
# #### Dempsey Wade

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
from sklearn import linear_model
from sklearn.feature_selection import RFE
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %% [markdown]
# ## Q1
#
# #### On the same graph, plot the functions sin(t), cos(t), and tan−1(t) where t is a vector from −10π to 10π with spacing 0.02. Label the x-axis and the y-axis “x-coordinate” and “y- coordinate” respectively and set the title of the graph to be “Some trigonometric functions”.

# %%
import math
import random

# %%
#Create my array of steps
t = np.arange(-10*math.pi, 10*math.pi, 0.02)

#Create list of functions 
sin = np.sin(t)
cos = np.cos(t)
tani = np.arctan(t)

#Plot the functions
plt.plot(t, sin, label = 'sin')
plt.plot(t, cos, label = 'cos')
plt.plot(t, tani, label = 'arctan')
plt.title("Some trigonometric functions")
plt.xlabel("x-coordinate")
plt.ylabel("y-coordinate")
plt.legend()
plt.show()

# %% [markdown]
# ## Q2
# #### Set a random seed equal to “38472” and generate two arrays “x” and “y” with 15 entries each. Set the size of the marker “s” equal to 90. Plot two subplots with the defined data next to each other. Set the marker for the first plot to be a filled circle and a “plus sign” for the second one. Repeat the exercise above, but now set the sequence of colours for your scatter plot to be sqrt(x2 + y2).

# %%
#Set seed
np.random.seed(38472)

#Generate random arrays of length 15
x = np.random.rand(15)
y = np.random.rand(15)

#First graph with specifications
plt.subplot(121)
plt.scatter(x, y, marker = 'o', s=90)

#second graph
plt.subplot(122)
plt.scatter(x, y, marker = '+', s=90)

plt.show()

# %%
#Second question

#Generate random arrays of length 15
x = np.random.rand(15)
y = np.random.rand(15)
z = np.sqrt(x**2 + y**2)

#First graph with specifications
plt.subplot(121)
plt.scatter(x, y, c=z, marker = 'o', s=90)

#second graph
plt.subplot(122)
plt.scatter(x, y, c=z, marker = '+', s=90)

plt.show()

# %% [markdown]
# ## Q3
# #### For this question, you will need to use the “seaborn” library. Load the seaborn dataset tips and visualize the first 5 rows of this dataset. Set the style of your plot to “ticks” and the colour palette to “pastel”. Display a nested boxplot to show the bills and the tips by day and time, and display whether the server was a smoker or not for each case. Repeat the same exercise, but this time, draw a set of horizontal bars.

# %%
#Import and visualize dataset
tips = sns.load_dataset('tips')
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Set specification for graphs
sns.set_style(style ='ticks')
sns.color_palette("pastel")

#Lots of information in this graph
sns.catplot(x='day', y='total_bill', hue='smoker', col='time',kind='box',data=tips)

# %%
#Box plot of tip

sns.catplot(x='total_bill', y='day', hue='smoker', 
            col='time', kind='bar', orient='h',data=tips)

# %% [markdown]
# ## Q4
# #### Load the seaborn dataset titanic and visualize the first 5 rows of this dataset. Set the style of your plot to “whitegrid”. Plot a scatter plot by passing the column names “fare” and “age” to the “x” and “y” axes, respectively. Make sure your plot shows the regression line.

# %%
#Import and visualize dataset dataset
titanic = sns.load_dataset('titanic')
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#Set specifications of graph
sns.set(style='whitegrid')

# %%
#Plot with regression line
sns.lmplot(x = 'fare', y='age', data = titanic)
plt.show()

# %% [markdown]
# ## Q5
# #### Load the seaborn dataset iris and visualize the first 10 rows of this dataset. Set the style of your plot to “darkgrid” and your palette to “muted”. Use the pandas library to un-pivot the columns “species” in your dataset to “measurements”. Produce a swarmplot by passing the column names “measurements” and “value” to the “x” and “y” axes, respectively.

# %%
#load and visualize the dataset
iris = sns.load_dataset('iris')
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#Melt the dataset to reorder data and create measurements
iris_melt = pd.melt(iris, 'species', var_name = 'measurement')
iris_melt.head(5)
# Out:
#   species   measurement  value
# 0  setosa  sepal_length    5.1
# 1  setosa  sepal_length    4.9
# 2  setosa  sepal_length    4.7
# 3  setosa  sepal_length    4.6
# 4  setosa  sepal_length    5.0

# %%
#Set graph specifications
sns.set(style = 'darkgrid', palette='muted')

#Graph
sns.swarmplot(x = 'measurement', y='value', data = iris_melt)
plt.show()
# Out:
# /Users/dwade/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning:
#
# 7.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /Users/dwade/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning:
#
# 32.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /Users/dwade/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning:
#
# 9.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /Users/dwade/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning:
#
# 26.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.

# %% [markdown]
# ## Q6
# #### Set a random seed equal to 2973 and define a random matrix “M” with dimension 10 × 15 and print it to screen. Produce two heatmaps of “M” using both the seaborn and the plotly library. Set the title on both plots to be “Matrix M”, the x-axis to be labeled “x values” and the y-axis to be labeled “y-values”.

# %%
#Set seed
np.random.seed(2973)

# %%
#Create matrix and display
M = np.random.rand(10,15)
M
# Out:
# array([[0.0876024 , 0.41232239, 0.87656989, 0.56750629, 0.93491933,
#         0.09954808, 0.62852921, 0.04798192, 0.70626034, 0.56597304,
#         0.01237379, 0.5432333 , 0.29414638, 0.41939833, 0.79163008],
#        [0.59712153, 0.21809528, 0.77521831, 0.25775332, 0.75333644,
#         0.49901496, 0.08928535, 0.09728087, 0.29050879, 0.15664534,
#         0.64741518, 0.37813052, 0.06842041, 0.86419701, 0.08275132],
#        [0.738645  , 0.04756234, 0.65284642, 0.90054164, 0.92731343,
#         0.45818133, 0.82967829, 0.69371545, 0.07190966, 0.66219733,
#         0.50844901, 0.44347898, 0.18137114, 0.96835626, 0.53027778],
#        [0.98690911, 0.02342536, 0.92391269, 0.99403292, 0.16137839,
#         0.16983025, 0.8275861 , 0.24203479, 0.06913303, 0.03343447,
#         0.96919964, 0.40533429, 0.44641583, 0.48417301, 0.46467999],
#        [0.33978249, 0.89383287, 0.86490424, 0.4238323 , 0.68331851,
#         0.80420626, 0.00507141, 0.6212552 , 0.2184031 , 0.63554857,
# ...

# %%
#Heatmap using seaborn
sns.heatmap(M).set_title("Matrix M")
plt.xlabel("x values")
plt.ylabel("y values")
plt.show()

# %%
#Heatmap using plotly, imports
import plotly.graph_objects as go
#import plotly.offline as pyo
#from plotly.offline import init_notebook_mode, iplot
# Set notebook mode to work in offline
#pyo.init_notebook_mode()

# %%
#Heatmap using plotly
#init_notebook_mode(connected=True)
fig = go.Figure(data=go.Heatmap(z=M))
fig.update_layout(title = 'Matrix M', xaxis_title='x values',
                 yaxis_title = 'y values')
#plt.savefig('q6.png')
fig.show()

# %% [markdown]
# ## Q7
# #### Import the dataset “tips” from plotly and set it equal to a variable called tipsData. Visualize the first 5 lines of your dataset. Produce a multiple violin plot from the tipsData dataset that has the tip amount on the y-axis and on the x-axis smoker and non-smoker workers grouped by sex.

# %%
#Import plotly
import plotly as pl
import plotly.express as px

#Import dataset and visualize
tipsData = pl.data.tips()
tipsData.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#violin plot
fig = px.violin(tipsData, y='tip',x='smoker',color='sex',box=True,
               points='all',hover_data=tipsData.columns)
fig.show()
