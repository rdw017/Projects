# %% [markdown]
# # Module 2 Live Coding Assignment:
# ## Introduction to Python

# %% [markdown]
# #### Dempsey Wade

# %%
import pandas as pd

# %% [markdown]
# ## Q1

# %%
country = {'Id':[1, 2, 3, 4, 5], 
           'Continent':['Europe', 'Europe', 'Asia', 'North America', 'Europe'],
           'Country':['Italy', 'France', 'China', 'Canada', 'Germany'],
           'Capital':['Rome','Paris','Beijing','Ottawa','Berlin']}

df = pd.DataFrame(country)
df = df.sort_values(by='Continent',ascending = False)
#df = df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#    Id      Continent  Country  Capital
# 3   4  North America   Canada   Ottawa
# 0   1         Europe    Italy     Rome
# 1   2         Europe   France    Paris
# 4   5         Europe  Germany   Berlin
# 2   3           Asia    China  Beijing

# %% [markdown]
# ## Q2

# %%
del df['Continent']
df.columns = ['Id','Country','Country Capital']
df.head()
# Out:
#    Id  Country Country Capital
# 3   4   Canada          Ottawa
# 0   1    Italy            Rome
# 1   2   France           Paris
# 4   5  Germany          Berlin
# 2   3    China         Beijing

# %% [markdown]
# ## Q3

# %%
df2 = pd.read_csv('/Users/dwade/Desktop/dartmouth/LiveCodingAssignments/Dartmouth Thayer_Data Science_Module 2_Live Coding Assignment/foo.csv')
df2
# Out:
#     id             firstName              lastName  billingId     product  \
# 0    1                  Luis           Alvarez$$%!        123        Cake
# 1    2                 André                Ampère        423        piza
# 2    3                 NiELS            Böhr//((%%        551       pizza
# 3    4                  PAUL                dirac$        521       pizza
# 4    5                Albert              Einstein        634       pizza
# 5    6               Galileo               GALiLEI        672       arepa
# 6    7                  CaRL              Ga%%%uss        323        taco
# 7    8                 David            H$$$ilbert        624    taaaccoo
# 8    9              Johannes                KEPLER        735        taco
# 9   10                 JaMES           M$$ax%%well        875        taco
# 10  11                 Isaac                Newton        992       pasta
# 11  12                Emmy%%              Nöether$        234       pasta
# ...

# %%
#Compute the average of the values in column price
average_price = df2['price'].mean()
print("Average Price: ", average_price)
# Out:
# Average Price:  6.052631578947368

# %%
#Get all prices less than or equal to 5
df_price = df2[df2['price'] <= 5]
df_price
# Out:
#     id firstName              lastName  billingId     product  price  \
# 5    6   Galileo               GALiLEI        672       arepa      5
# 6    7      CaRL              Ga%%%uss        323        taco      3
# 7    8     David            H$$$ilbert        624    taaaccoo      3
# 8    9  Johannes                KEPLER        735        taco      3
# 9   10     JaMES           M$$ax%%well        875        taco      3
# 12  13    Max!!!             Planck!!!        111  hamburguer      4
# 15  16   William            Gilbert###        886        BEER      2
# 16  17     Marie                 CURIE        912        Rice      1
# 17  18    Arthur            COM%%%pton        812      110790      5
#
#          birth dummyCol
# 5   12-08-1930    never
# 6   13-07-1970    gonna
# 7   14-07-1950      let
# 8   22-04-1920      you
# 9   12-03-1923     down
# 12  04-01-1994     run
# 15  26-03-1958   desert
# 16  22-03-2000      you
# 17  1899/01/01        #

# %% [markdown]
# ## Q4

# %%
add_ten = lambda x: x+10

added_values = df2.assign(billingId = add_ten(df2['billingId']))
added_values
# Out:
#     id             firstName              lastName  billingId     product  \
# 0    1                  Luis           Alvarez$$%!        133        Cake
# 1    2                 André                Ampère        433        piza
# 2    3                 NiELS            Böhr//((%%        561       pizza
# 3    4                  PAUL                dirac$        531       pizza
# 4    5                Albert              Einstein        644       pizza
# 5    6               Galileo               GALiLEI        682       arepa
# 6    7                  CaRL              Ga%%%uss        333        taco
# 7    8                 David            H$$$ilbert        634    taaaccoo
# 8    9              Johannes                KEPLER        745        taco
# 9   10                 JaMES           M$$ax%%well        885        taco
# 10  11                 Isaac                Newton       1002       pasta
# 11  12                Emmy%%              Nöether$        244       pasta
# ...

# %% [markdown]
# ## Q5

# %%
df2_even = df2[df2['id']%2 == 0]

df2_even
# Out:
#     id firstName              lastName  billingId   product  price  \
# 1    2     André                Ampère        423      piza      8
# 3    4      PAUL                dirac$        521     pizza      8
# 5    6   Galileo               GALiLEI        672     arepa      5
# 7    8     David            H$$$ilbert        624  taaaccoo      3
# 9   10     JaMES           M$$ax%%well        875      taco      3
# 11  12    Emmy%%              Nöether$        234     pasta      9
# 13  14      Fred              Hoy&&&le        553    pizzza      8
# 15  16   William            Gilbert###        886      BEER      2
# 17  18    Arthur            COM%%%pton        812    110790      5
#
#          birth dummyCol
# 1   08-07-1950    gonna
# 3   10-07-1954      you
# 5   12-08-1930    never
# 7   14-07-1950      let
# 9   12-03-1923     down
# 11  08-12-1993    gonna
# 13  27-06-1997   around
# 15  26-03-1958   desert
# 17  1899/01/01        #

# %%
df2_odd = df2[df2['id']%2 == 1]

df2_odd
# Out:
#     id             firstName     lastName  billingId     product  price  \
# 0    1                  Luis  Alvarez$$%!        123        Cake     10
# 2    3                 NiELS   Böhr//((%%        551       pizza      8
# 4    5                Albert     Einstein        634       pizza      8
# 6    7                  CaRL     Ga%%%uss        323        taco      3
# 8    9              Johannes       KEPLER        735        taco      3
# 10  11                 Isaac       Newton        992       pasta      9
# 12  13                Max!!!    Planck!!!        111  hamburguer      4
# 14  15  (((   Heinrich )))))        Hertz        116       pizza      8
# 16  17                 Marie        CURIE        912        Rice      1
# 18  19                 JAMES     Chadwick        467         NaN     10
#
#          birth dummyCol
# 0   07-07-1980    never
# 2   09-07-1990     give
# 4   11-07-1990       up
# 6   13-07-1970    gonna
# 8   22-04-1920      you
# 10  15-02-1999   never
# ...
